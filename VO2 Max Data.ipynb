# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.pyplot import figure

# %%
df= pd.read_csv('C:/Users/epicr/Downloads/HeartRate.csv')

# %%
df
# Out:
#      Time HeartRate
# 0    1:00        79
# 1    2:00        77
# 2    3:00        74
# 3    4:00        79
# 4    5:00        84
# 5    6:00        95
# 6    7:00       110
# 7    8:00       121
# 8    9:00       125
# 9   10:00       133
# 10  11:00       138
# 11  12:00       137
# 12  13:00       137
# 13  14:00       143
# 14  15:00       141
# 15  16:00       108
# 16  17:00       104
# 17  18:00        99
# 18  19:00        98
# 19  20:00        99

# %%
df['HeartRate']= df['HeartRate'].astype(int)
df['Time']= df['Time'].astype(str)

# %%
plt.figure(figsize=(25,10))
plt.plot(df['Time'], df['HeartRate'], color='green', linewidth='4')

# %%
df.dtypes
# Out:
# Time         object
# HeartRate    object
# dtype: object
